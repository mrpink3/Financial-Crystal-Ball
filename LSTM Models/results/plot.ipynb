# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
test_results = pd.read_csv("test_predictions_Regression.csv")

# %%
test_results
# Out:
#           True  Predicted
# 0     0.002993  -0.006643
# 1    -0.000260   0.002885
# 2    -0.004598  -0.000713
# 3    -0.001681  -0.008293
# 4    -0.119679  -0.000369
# ...        ...        ...
# 1056 -0.010306   0.000217
# 1057  0.000044   0.003672
# 1058  0.000044  -0.001655
# 1059  0.008965  -0.000657
# 1060  0.006769   0.001440
#
# [1061 rows x 2 columns]

# %%
# Plot the predictions vs actual returns
plt.figure(figsize=(14, 7))
plt.plot(test_results['True'], label='Actual Return', color='blue', alpha=0.5)
plt.plot(test_results['Predicted'], label='Predicted Return', color='red', alpha=0.5)
plt.title('LSTM Regression: Actual vs Predicted Returns')
plt.xlabel('Sample Index')
plt.ylabel('Return')
plt.legend()
plt.grid()
plt.show()
